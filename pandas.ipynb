# %%
import pandas as pd

df=pd.read_csv('ACM.csv')
df.head()
# Out:
#              Timestamp          Full Name                   Email address  \
# 0  11/28/2023 16:22:25       Aiman fatima      Aymanchudhary507@gmail.com
# 1  11/28/2023 22:49:05      Raza maqsood    razamaqsood.gcu.edu@gmail.com
# 2   11/29/2023 1:11:22          Muhammad              madnimm07@gmail.com
# 3  11/29/2023 12:48:17   Gull-Zareen Khan  Gullzareenkhan125693@gmail.com
# 4  11/29/2023 12:50:05  Sana Ehsan ul haq        sanaahsanulhaq@gmail.com
#
#   Phone number(WhatsApp)     Semester              Department   Section  \
# 0            03361610715  1st semester       Computer Science  Evening
# 1            03304573521           5th      Computer science         E2
# 2            03104973683             5                   BSCS        E1
# 3             3354738606           1st  Software Engineering         A1
# 4            03241471760           1st   Software engineering        A1
#
#   Roll no (e.g. xxxx-BSCS-xx)   \
# 0                 0127-BSCS-23
# 1                 0296-BSCS-21
# 2                 0241-bscs-21
# 3                 6433-BSSE-23
# 4                6450-BS-SE-23
#
#   Please indicate your preference for participation:  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Which team do you want to join? (you can select only two options).  \
# 0                        Content Team, Creative Team
# 1           Content Team, Stage Team, Publicity Team
# 2                       Publicity Team, Finance Team
# 3                     Gaming Team, Social media Team
# 4                   Creative Team, Social media Team
#
#   How do  you want to pay your registration fee?  \
# 0                                         Online
# 1                                           Cash
# 2                               Still to be paid
# 3                                           Cash
# 4                                           Cash
#
#   Attach the proof of you online/cash payment below (file size up to 1mb,jpg,png).\n\nPlease give us proof ASAP so we can add you to our meeting schedule for interviews.  \
# 0  https://drive.google.com/open?id=1PAmuIB37PjJw...
# 1  https://drive.google.com/open?id=1YpScjFpmHV_1...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Acknowledgment: I hereby acknowledge that I have read the above information carefully, including the details about the registration fee and payment process.
# 0        I have read and understood the information.
# 1        I have read and understood the information.
# 2        I have read and understood the information.
# 3        I have read and understood the information.
# 4        I have read and understood the information.

# %%
tempdict={'col1':[1,2,3],'col2':[4,5,6],'col3':[7,8,9]}
dictdf=pd.DataFrame.from_dict(tempdict)

# %%
dictdf.head()
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6     9

# %% [raw]
# READ

# %%
df.tail()
# Out:
#     Timestamp         Full Name               Email address  \
# 104       NaN           Farheen   farheemrahmanfr@gmail.com
# 105       NaN      Wajeeha Butt    wajeehabutt614@gmail.com
# 106       NaN  Muhammad Luqman        mluqman4755@gmail.com
# 107       NaN    Javeria inayat  javeriainayat047@gmail.com
# 108       NaN     Muneeb Hassan       muneebh4407@gmail.com
#
#     Phone number(WhatsApp) Semester  Department Section  \
# 104           0333 8163334       1st        NaN     NaN
# 105            03224034728       3rd         CS     NaN
# 106           '03054755092       6th         CS     NaN
# 107           '03334401062         1        NaN     NaN
# 108             3226955476         1        NaN     NaN
#
#     Roll no (e.g. xxxx-BSCS-xx)   \
# 104                          NaN
# 105                 0033-BSCS-22
# 106                 0033-BSCS-21
# 107                 0117-BSCS-23
# 108                          NaN
#
#     Please indicate your preference for participation:  \
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
# 107                                                NaN
# 108                                                NaN
#
#     Which team do you want to join? (you can select only two options).  \
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
# 107                                                NaN
# 108                                                NaN
#
#     How do  you want to pay your registration fee?  \
# 104                                            NaN
# 105                                            NaN
# 106                                            NaN
# 107                                            NaN
# 108                                            NaN
#
#     Attach the proof of you online/cash payment below (file size up to 1mb,jpg,png).\n\nPlease give us proof ASAP so we can add you to our meeting schedule for interviews.  \
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
# 107                                                NaN
# 108                                                NaN
#
#     Acknowledgment: I hereby acknowledge that I have read the above information carefully, including the details about the registration fee and payment process.
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
# 107                                                NaN
# 108                                                NaN

# %%
df.head(15)
# Out:
#               Timestamp           Full Name                   Email address  \
# 0   11/28/2023 16:22:25        Aiman fatima      Aymanchudhary507@gmail.com
# 1   11/28/2023 22:49:05       Raza maqsood    razamaqsood.gcu.edu@gmail.com
# 2    11/29/2023 1:11:22           Muhammad              madnimm07@gmail.com
# 3   11/29/2023 12:48:17    Gull-Zareen Khan  Gullzareenkhan125693@gmail.com
# 4   11/29/2023 12:50:05   Sana Ehsan ul haq        sanaahsanulhaq@gmail.com
# 5   11/29/2023 12:52:17         Sana Batool      sanabatool18m147@gmail.com
# 6   11/29/2023 12:54:33          Eman Iqbal       iman.iqbal12204@gmail.com
# 7   11/29/2023 12:54:53          Hanya Khan        haniyakhan1718@gmail.com
# 8   11/29/2023 12:56:41       Zourain Bano            zourainbano@gmail.com
# 9   11/29/2023 12:57:42  Ahmad Rasool Tahir        ahmadtahir1058@gmail.com
# 10  11/29/2023 12:59:33   Sana Ehsan ul haq        sanaahsanulhaq@gmail.com
# 11  11/29/2023 12:59:36    Gull-Zareen Khan  gullzareenkhan125693@gmail.com
# 12  11/29/2023 12:59:56        Saman Saeed              smmnsaeed@gmail.com
# 13  11/29/2023 13:00:29   Ahmad Ali Arshad       ahmadaliarshad23@gmail.com
# 14  11/29/2023 13:01:09  Ahmad Rasool Tahir        ahmadtahir1058@gmail.com
#
#    Phone number(WhatsApp)     Semester                Department  \
# 0             03361610715  1st semester         Computer Science
# 1             03304573521           5th        Computer science
# 2             03104973683             5                     BSCS
# 3              3354738606           1st    Software Engineering
# 4             03241471760           1st     Software engineering
# 5             03141465045           1st        Computer science
# 6             03338086322             1         Computer Science
# 7             03364257809           1st     software engineering
# 8             03284300019            01    Software engineering
# 9             03011435329          1st      Software engenering
# 10            03241471760           1st     Software engineering
# 11            03354738606           1st     software engineering
# 12            03004138220             1    Software engineering
# 13            03219040496   First (1st)        Computer Science
# 14            03011435329           1st  Bs software engenering
#
#          Section Roll no (e.g. xxxx-BSCS-xx)   \
# 0       Evening                  0127-BSCS-23
# 1             E2                 0296-BSCS-21
# 2             E1                 0241-bscs-21
# 3             A1                 6433-BSSE-23
# 4             A1                6450-BS-SE-23
# 5             A1                6411-BS-SE-23
# 6             A1                 0005-BSCS-23
# 7             A1                 6440-BSCS-23
# 8             A1                 6436-BSSE-23
# 9             A1                 6429-BSSE-23
# 10            A1                6450-BS-SE-23
# 11            A1                 6433-BSCS-23
# 12            A1             6406 - BS-SE -23
# 13  A1 (Morning)                 0019-BSCS-23
# 14            A1                 6429-BSSE-23
#
#    Please indicate your preference for participation:  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#    Which team do you want to join? (you can select only two options).  \
# 0                         Content Team, Creative Team
# 1            Content Team, Stage Team, Publicity Team
# 2                        Publicity Team, Finance Team
# 3                      Gaming Team, Social media Team
# 4                    Creative Team, Social media Team
# 5          Gaming Team, Social Team, Photography Team
# 6                     Content Team, Social media Team
# 7                         Content Team, Creative Team
# 8                     Content Team, Social media Team
# 9   Photography Team, Social media Team, Videograp...
# 10                   Creative Team, Social media Team
# 11        Gaming Team, Social Team, Social media Team
# 12                   Creative Team, Social media Team
# 13                   Graphics Team, Social media Team
# 14  Creative Team, Photography Team, Social media ...
#
#    How do  you want to pay your registration fee?  \
# 0                                          Online
# 1                                            Cash
# 2                                Still to be paid
# 3                                            Cash
# 4                                            Cash
# 5                                            Cash
# 6                                            Cash
# 7                                            Cash
# 8                                            Cash
# 9                                            Cash
# 10                                           Cash
# 11                                           Cash
# 12                                           Cash
# 13                                           Cash
# 14                                           Cash
#
#    Attach the proof of you online/cash payment below (file size up to 1mb,jpg,png).\n\nPlease give us proof ASAP so we can add you to our meeting schedule for interviews.  \
# 0   https://drive.google.com/open?id=1PAmuIB37PjJw...
# 1   https://drive.google.com/open?id=1YpScjFpmHV_1...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   https://drive.google.com/open?id=1_PsTJxNn-d-c...
# 6   https://drive.google.com/open?id=1kpOvGU1pJzGz...
# 7   https://drive.google.com/open?id=1JMFO1iaEbluj...
# 8   https://drive.google.com/open?id=1icxuZfqsZ3wA...
# 9   https://drive.google.com/open?id=13eEVO8PnKir2...
# 10  https://drive.google.com/open?id=1Lrsf_tR-ZQlp...
# 11  https://drive.google.com/open?id=1cwaDXlVVFUkR...
# 12  https://drive.google.com/open?id=1rf0JORnMA4FC...
# 13  https://drive.google.com/open?id=1Fnbg3KLTBC0E...
# 14  https://drive.google.com/open?id=1zDmPn2x45517...
#
#    Acknowledgment: I hereby acknowledge that I have read the above information carefully, including the details about the registration fee and payment process.
# 0         I have read and understood the information.
# 1         I have read and understood the information.
# 2         I have read and understood the information.
# 3         I have read and understood the information.
# 4         I have read and understood the information.
# 5         I have read and understood the information.
# 6         I have read and understood the information.
# 7         I have read and understood the information.
# 8         I have read and understood the information.
# 9         I have read and understood the information.
# 10        I have read and understood the information.
# 11        I have read and understood the information.
# 12        I have read and understood the information.
# 13        I have read and understood the information.
# 14        I have read and understood the information.

# %%
df.columns
# Out:
# Index(['Timestamp', 'Full Name', 'Email address', 'Phone number(WhatsApp)',
#        'Semester ', 'Department', 'Section', 'Roll no (e.g. xxxx-BSCS-xx) ',
#        'Please indicate your preference for participation:',
#        'Which team do you want to join? (you can select only two options).',
#        'How do  you want to pay your registration fee?',
#        'Attach the proof of you online/cash payment below (file size up to 1mb,jpg,png).\n\nPlease give us proof ASAP so we can add you to our meeting schedule for interviews.',
#        'Acknowledgment: I hereby acknowledge that I have read the above information carefully, including the details about the registration fee and payment process.'],
#       dtype='object')

# %%
df.dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2440\1115469300.py in ?()
# ----> 1 df.dtype
#
# D:\PANDAS\pandas_venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
df.dtypes
# Out:
# Timestamp                                                                                                                                                                  object
# Full Name                                                                                                                                                                  object
# Email address                                                                                                                                                              object
# Phone number(WhatsApp)                                                                                                                                                     object
# Semester                                                                                                                                                                   object
# Department                                                                                                                                                                 object
# Section                                                                                                                                                                    object
# Roll no (e.g. xxxx-BSCS-xx)                                                                                                                                                object
# Please indicate your preference for participation:                                                                                                                         object
# Which team do you want to join? (you can select only two options).                                                                                                         object
# How do  you want to pay your registration fee?                                                                                                                             object
# Attach the proof of you online/cash payment below (file size up to 1mb,jpg,png).\n\nPlease give us proof ASAP so we can add you to our meeting schedule for interviews.    object
# Acknowledgment: I hereby acknowledge that I have read the above information carefully, including the details about the registration fee and payment process.               object
# dtype: object

# %% [markdown]
# SUMMARY STATISTICS

# %%
df.describe()
# Out:
#                   Timestamp          Full Name               Email address  \
# count                   104                109                         109
# unique                  104                 89                          87
# top     11/28/2023 16:22:25  Ahmad Ali Arshad   ahmadaliarshad23@gmail.com
# freq                      1                  4                           4
#
#        Phone number(WhatsApp) Semester          Department Section  \
# count                     109       109                106      99
# unique                     87        20                 36      31
# top               03219040496       1st  Computer science       A1
# freq                        4        44                 17      44
#
#        Roll no (e.g. xxxx-BSCS-xx)   \
# count                           107
# unique                           85
# top                    0019-BSCS-23
# freq                              4
#
#        Please indicate your preference for participation:  \
# count                                                  68
# unique                                                  2
# top     I would like to join as part of a team. (If ye...
# freq                                                   54
#
#        Which team do you want to join? (you can select only two options).  \
# count                                                  94
# unique                                                 47
# top                      Graphics Team, Social media Team
# freq                                                    7
#
#        How do  you want to pay your registration fee?  \
# count                                             104
# unique                                              3
# top                                              Cash
# freq                                               77
#
#        Attach the proof of you online/cash payment below (file size up to 1mb,jpg,png).\n\nPlease give us proof ASAP so we can add you to our meeting schedule for interviews.  \
# count                                                  98
# unique                                                 98
# top     https://drive.google.com/open?id=1PAmuIB37PjJw...
# freq                                                    1
#
#        Acknowledgment: I hereby acknowledge that I have read the above information carefully, including the details about the registration fee and payment process.
# count                                                 104
# unique                                                  1
# top           I have read and understood the information.
# freq                                                  104

# %%
df.describe(include='object')
# Out:
#                   Timestamp          Full Name               Email address  \
# count                   104                109                         109
# unique                  104                 89                          87
# top     11/28/2023 16:22:25  Ahmad Ali Arshad   ahmadaliarshad23@gmail.com
# freq                      1                  4                           4
#
#        Phone number(WhatsApp) Semester          Department Section  \
# count                     109       109                106      99
# unique                     87        20                 36      31
# top               03219040496       1st  Computer science       A1
# freq                        4        44                 17      44
#
#        Roll no (e.g. xxxx-BSCS-xx)   \
# count                           107
# unique                           85
# top                    0019-BSCS-23
# freq                              4
#
#        Please indicate your preference for participation:  \
# count                                                  68
# unique                                                  2
# top     I would like to join as part of a team. (If ye...
# freq                                                   54
#
#        Which team do you want to join? (you can select only two options).  \
# count                                                  94
# unique                                                 47
# top                      Graphics Team, Social media Team
# freq                                                    7
#
#        How do  you want to pay your registration fee?  \
# count                                             104
# unique                                              3
# top                                              Cash
# freq                                               77
#
#        Attach the proof of you online/cash payment below (file size up to 1mb,jpg,png).\n\nPlease give us proof ASAP so we can add you to our meeting schedule for interviews.  \
# count                                                  98
# unique                                                 98
# top     https://drive.google.com/open?id=1PAmuIB37PjJw...
# freq                                                    1
#
#        Acknowledgment: I hereby acknowledge that I have read the above information carefully, including the details about the registration fee and payment process.
# count                                                 104
# unique                                                  1
# top           I have read and understood the information.
# freq                                                  104

# %%
df.Department
# Out:
# 0           Computer Science
# 1          Computer science
# 2                       BSCS
# 3      Software Engineering
# 4       Software engineering
#                ...
# 104                      NaN
# 105                       CS
# 106                       CS
# 107                      NaN
# 108                      NaN
# Name: Department, Length: 109, dtype: object

# %%
df['Full Name']
# Out:
# 0           Aiman fatima
# 1          Raza maqsood
# 2              Muhammad
# 3       Gull-Zareen Khan
# 4      Sana Ehsan ul haq
#              ...
# 104              Farheen
# 105         Wajeeha Butt
# 106     Muhammad Luqman
# 107       Javeria inayat
# 108        Muneeb Hassan
# Name: Full Name, Length: 109, dtype: object

# %%
df[['Full Name','Department' ]]
# Out:
#              Full Name             Department
# 0         Aiman fatima       Computer Science
# 1        Raza maqsood       Computer science
# 2            Muhammad                    BSCS
# 3     Gull-Zareen Khan  Software Engineering
# 4    Sana Ehsan ul haq   Software engineering
# ..                 ...                    ...
# 104            Farheen                    NaN
# 105       Wajeeha Butt                     CS
# 106   Muhammad Luqman                      CS
# 107     Javeria inayat                    NaN
# 108      Muneeb Hassan                    NaN
#
# [109 rows x 2 columns]

# %%
df[df['Department']=='CS']
# Out:
#               Timestamp         Full Name               Email address  \
# 94   12/7/2023 18:04:37    RUBAB RAFIQUE   rubabrafique512@gmail.com
# 105                 NaN      Wajeeha Butt    wajeehabutt614@gmail.com
# 106                 NaN  Muhammad Luqman        mluqman4755@gmail.com
#
#     Phone number(WhatsApp) Semester  Department Section  \
# 94             03024091458     First         CS      AI
# 105            03224034728       3rd         CS     NaN
# 106           '03054755092       6th         CS     NaN
#
#     Roll no (e.g. xxxx-BSCS-xx)   \
# 94                  6307-BSCS-AI
# 105                 0033-BSCS-22
# 106                 0033-BSCS-21
#
#     Please indicate your preference for participation:  \
# 94   I would like to join as part of a team. (If ye...
# 105                                                NaN
# 106                                                NaN
#
#     Which team do you want to join? (you can select only two options).  \
# 94                                       Graphics Team
# 105                                                NaN
# 106                                                NaN
#
#     How do  you want to pay your registration fee?  \
# 94                                            Cash
# 105                                            NaN
# 106                                            NaN
#
#     Attach the proof of you online/cash payment below (file size up to 1mb,jpg,png).\n\nPlease give us proof ASAP so we can add you to our meeting schedule for interviews.  \
# 94   https://drive.google.com/open?id=13zPWz9LaSc7T...
# 105                                                NaN
# 106                                                NaN
#
#     Acknowledgment: I hereby acknowledge that I have read the above information carefully, including the details about the registration fee and payment process.
# 94         I have read and understood the information.
# 105                                                NaN
# 106                                                NaN

# %%
df[(df['Department']=='ComputerScience')&(df['Section']=='A1')]
# Out:
# Empty DataFrame
# Columns: [Timestamp, Full Name, Email address, Phone number(WhatsApp), Semester , Department, Section, Roll no (e.g. xxxx-BSCS-xx) , Please indicate your preference for participation:, Which team do you want to join? (you can select only two options)., How do  you want to pay your registration fee?, Attach the proof of you online/cash payment below (file size up to 1mb,jpg,png).
#
# Please give us proof ASAP so we can add you to our meeting schedule for interviews., Acknowledgment: I hereby acknowledge that I have read the above information carefully, including the details about the registration fee and payment process.]
# Index: []

# %%
df.iloc[14]
# Out:
# Timestamp                                                                                                                                                                                                11/29/2023 13:01:09
# Full Name                                                                                                                                                                                                 Ahmad Rasool Tahir
# Email address                                                                                                                                                                                       ahmadtahir1058@gmail.com
# Phone number(WhatsApp)                                                                                                                                                                                           03011435329
# Semester                                                                                                                                                                                                                 1st
# Department                                                                                                                                                                                           Bs software engenering
# Section                                                                                                                                                                                                                   A1
# Roll no (e.g. xxxx-BSCS-xx)                                                                                                                                                                                     6429-BSSE-23
# Please indicate your preference for participation:                                                                                                                                                                       NaN
# Which team do you want to join? (you can select only two options).                                                                                                         Creative Team, Photography Team, Social media ...
# How do  you want to pay your registration fee?                                                                                                                                                                          Cash
# Attach the proof of you online/cash payment below (file size up to 1mb,jpg,png).\n\nPlease give us proof ASAP so we can add you to our meeting schedule for interviews.    https://drive.google.com/open?id=1zDmPn2x45517...
# Acknowledgment: I hereby acknowledge that I have read the above information carefully, including the details about the registration fee and payment process.                     I have read and understood the information.
# Name: 14, dtype: object

# %%
df.iloc[12,-1]
# Out:
# 'I have read and understood the information.'

# %%
df.iloc[22:33]
# Out:
#               Timestamp      Full Name                Email address  \
# 22  11/29/2023 15:34:07   Irzam Irshad       irzamhpelite@gmail.com
# 23  11/29/2023 15:43:03  Mariyam Khan           malodhi14@gmail.com
# 24  11/29/2023 16:47:55     Anas Tahir       tahiranas987@gmail.com
# 25  11/29/2023 16:56:12          Sijal      parisabbas637@gmail.com
# 26  11/29/2023 17:01:14    Laiba iqbal    iqbalkhanlaiba5@gmail.com
# 27  11/29/2023 17:03:25  Ayesha Shahid    shahidayesha014@gmail.com
# 28  11/29/2023 17:25:36   Abdul Wahab     abdulwahab08025@gmail.com
# 29  11/29/2023 17:31:38  Ali Abdullah   itz.abdul.ali.888@gmail.com
# 30  11/29/2023 18:08:11  Muhammad Raza        razaalee135@gmail.com
# 31  11/29/2023 18:09:25  Aman Iftikhar   amaniftikhar5645@gmail.com
# 32  11/29/2023 18:32:00     Faria Saif        fariasaif05@gmail.com
#
#    Phone number(WhatsApp)        Semester                 Department  \
# 22            03316711938                1          Computer science
# 23            03241524463               1E            BS CS evening
# 24           0321 6967893              1st  Artificial Intelligence
# 25            03174004053                1         Computer science
# 26            03463766747              1st         Computer science
# 27            03248579513              1st          Computer Science
# 28           0309 3211168              1st         Computer Science
# 29           0311 0645296    1st Semester          Computer science
# 30             3490688785              1st                      BSAI
# 31            03164540243              1st          Computer Science
# 32            03304183364  First semester          Computer Science
#
#                     Section Roll no (e.g. xxxx-BSCS-xx)   \
# 22                 Evening                  0152-BSCS-23
# 23                 Evening                0113-BSCS-2023
# 24                       A1                 6301-BSAI-23
# 25                       A1                 6303-BSAI-23
# 26                       A1                 6339-BSAI-23
# 27                       A1                 6443-BSSE-23
# 28                       A1                 0008-BSCS-23
# 29              A1- Morning                 0012-BSCS-23
# 30                      NaN                 6338-BSAI-23
# 31  Artificial Intelligence                 6308-BSAI-23
# 32                 CS-A1-23                 0033-BSCS-23
#
#    Please indicate your preference for participation:  \
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
#
#    Which team do you want to join? (you can select only two options).  \
# 22                                  Social media Team
# 23                        Content Team, Creative Team
# 24                      Gaming Team, Photography Team
# 25                        Creative Team, Finance Team
# 26                   Graphics Team, Social media Team
# 27                       Creative Team, Graphics Team
# 28                                  Social media Team
# 29                Social media Team, Videography Team
# 30                    Graphics Team, Videography Team
# 31                    Graphics Team, Videography Team
# 32                   Graphics Team, Social media Team
#
#    How do  you want to pay your registration fee?  \
# 22                                         Online
# 23                                           Cash
# 24                                         Online
# 25                                           Cash
# 26                                         Online
# 27                                           Cash
# 28                                           Cash
# 29                                           Cash
# 30                                           Cash
# 31                                           Cash
# 32                                           Cash
#
#    Attach the proof of you online/cash payment below (file size up to 1mb,jpg,png).\n\nPlease give us proof ASAP so we can add you to our meeting schedule for interviews.  \
# 22  https://drive.google.com/open?id=1XCcMS4F93R3K...
# 23  https://drive.google.com/open?id=1FQR7aDRT0x_4...
# 24  https://drive.google.com/open?id=1Uba0eQKYxtON...
# 25                                                NaN
# 26  https://drive.google.com/open?id=1mfnik5H6Sebc...
# 27  https://drive.google.com/open?id=1_FbCwjS0ivYs...
# 28  https://drive.google.com/open?id=1j6ClU8q1H14U...
# 29  https://drive.google.com/open?id=199jUvuSVPb2C...
# 30  https://drive.google.com/open?id=16zSpiLy87oi0...
# 31  https://drive.google.com/open?id=1c45Oq9KCoiow...
# 32  https://drive.google.com/open?id=1-a9zxMbu3VtO...
#
#    Acknowledgment: I hereby acknowledge that I have read the above information carefully, including the details about the registration fee and payment process.
# 22        I have read and understood the information.
# 23        I have read and understood the information.
# 24        I have read and understood the information.
# 25        I have read and understood the information.
# 26        I have read and understood the information.
# 27        I have read and understood the information.
# 28        I have read and understood the information.
# 29        I have read and understood the information.
# 30        I have read and understood the information.
# 31        I have read and understood the information.
# 32        I have read and understood the information.

# %%
df.copy()
df.set_index('Email',inplace='true')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 2
#       1 df.copy()
# ----> 2 df.set_index('Email',inplace='true')
#
# File D:\PANDAS\pandas_venv\Lib\site-packages\pandas\core\frame.py:6091, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5993 def set_index(
#    5994     self,
#    5995     keys,
#    (...)
#    6000     verify_integrity: bool = False,
#    6001 ) -> DataFrame | None:
#    6002     """
#    6003     Set the DataFrame index using existing columns.
#    6004
#    (...)
#    6089     4 16     10  2014    31
#    6090     """
# -> 6091     inplace = validate_bool_kwarg(inplace, "inplace")
#    6092     self._check_inplace_and_allows_duplicate_labels(inplace)
#    6093     if not isinstance(keys, list):
#
# File D:\PANDAS\pandas_venv\Lib\site-packages\pandas\util\_validators.py:264, in validate_bool_kwarg(value, arg_name, none_allowed, int_allowed)
#     261     good_value = good_value or isinstance(value, int)
#     263 if not good_value:
# --> 264     raise ValueError(
#     265         f'For argument "{arg_name}" expected type bool, received '
#     266         f"type {type(value).__name__}."
#     267     )
#     268 return value
#
# ValueError: For argument "inplace" expected type bool, received type str.

# %%
df=df.rename({'Phone number(WhatsApp)':'Whatsapp_Number'},axis='columns')

# %%
df.columns
# Out:
# Index(['Timestamp', 'Full Name', 'Email address', 'Whatsapp_Number',
#        'Semester ', 'Department', 'Section', 'Roll no (e.g. xxxx-BSCS-xx) ',
#        'Please indicate your preference for participation:',
#        'Which team do you want to join? (you can select only two options).',
#        'How do  you want to pay your registration fee?',
#        'Attach the proof of you online/cash payment below (file size up to 1mb,jpg,png).\n\nPlease give us proof ASAP so we can add you to our meeting schedule for interviews.',
#        'Acknowledgment: I hereby acknowledge that I have read the above information carefully, including the details about the registration fee and payment process.'],
#       dtype='object')

# %%
df.columns=df.columns.str.replace(' ','_')

# %%
df.columns
# Out:
# Index(['Timestamp', 'Full_Name', 'Email_address', 'Whatsapp_Number',
#        'Semester_', 'Department', 'Section', 'Roll_no_(e.g._xxxx-BSCS-xx)_',
#        'Please_indicate_your_preference_for_participation:',
#        'Which_team_do_you_want_to_join?_(you_can_select_only_two_options).',
#        'How_do__you_want_to_pay_your_registration_fee?',
#        'Attach_the_proof_of_you_online/cash_payment_below_(file_size_up_to_1mb,jpg,png).\n\nPlease_give_us_proof_ASAP_so_we_can_add_you_to_our_meeting_schedule_for_interviews.',
#        'Acknowledgment:_I_hereby_acknowledge_that_I_have_read_the_above_information_carefully,_including_the_details_about_the_registration_fee_and_payment_process.'],
#       dtype='object')

# %%
df.columns=df.columns.str.replace('_','')

# %%
df=df.rename({'Semester ':'Semester'},axis='columns')
